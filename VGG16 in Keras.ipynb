# %% [markdown]
# VGG16 pruebas iniciales

# %%
# !wget --no-check-certificate \
  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
  -O cats_and_dogs_filtered.zip
# Out:
# --2022-05-24 14:39:01--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.115.128, 172.253.122.128, 172.253.63.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.115.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip’
#
# cats_and_dogs_filte 100%[===================>]  65.43M   185MB/s    in 0.4s
#
# 2022-05-24 14:39:01 (185 MB/s) - ‘cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
! unzip cats_and_dogs_filtered.zip

# %%
import keras,os
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory="cats_and_dogs_filtered/train",target_size=(224,224))
tsdata = ImageDataGenerator()
testdata = tsdata.flow_from_directory(directory="cats_and_dogs_filtered/validation", target_size=(224,224))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
model = Sequential(name="VGG16")
model.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=2, activation="softmax"))

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999)
opt = tf.keras.optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)

model.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "VGG16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_52 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_53 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_20 (MaxPoolin  (None, 112, 112, 64)     0
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_55 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_21 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_56 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_57 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_58 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_22 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_59 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_60 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_61 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_23 (MaxPoolin  (None, 14, 14, 512)      0
#  g2D)
#
#  conv2d_62 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_63 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_64 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_24 (MaxPoolin  (None, 7, 7, 512)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 25088)             0
#
#  dense_12 (Dense)            (None, 4096)              102764544
#
#  dense_13 (Dense)            (None, 4096)              16781312
#
#  dense_14 (Dense)            (None, 2)                 8194
#
# =================================================================
# Total params: 134,268,738
# Trainable params: 134,268,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')

# %%
# hist = model.fit(traindata, steps_per_epoch=100, validation_data=testdata, validation_steps=10,epochs=100,callbacks=[checkpoint,early])

batch_size=32
n_epochs=100

hist = model.fit(traindata, batch_size=batch_size, validation_data=testdata,epochs=n_epochs,callbacks=[checkpoint,early])
# Out:
# Epoch 1/100
# 63/63 [==============================] - ETA: 0s - loss: 0.8018 - accuracy: 0.4830
# Epoch 1: val_accuracy improved from -inf to 0.53400, saving model to vgg16_1.h5
# 63/63 [==============================] - 44s 682ms/step - loss: 0.8018 - accuracy: 0.4830 - val_loss: 0.6902 - val_accuracy: 0.5340
# Epoch 2/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6885 - accuracy: 0.5335
# Epoch 2: val_accuracy did not improve from 0.53400
# 63/63 [==============================] - 36s 564ms/step - loss: 0.6885 - accuracy: 0.5335 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 3/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5130
# Epoch 3: val_accuracy did not improve from 0.53400
# 63/63 [==============================] - 35s 555ms/step - loss: 0.6918 - accuracy: 0.5130 - val_loss: 0.7124 - val_accuracy: 0.5300
# Epoch 4/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6799 - accuracy: 0.5480
# Epoch 4: val_accuracy improved from 0.53400 to 0.60600, saving model to vgg16_1.h5
# 63/63 [==============================] - 42s 661ms/step - loss: 0.6799 - accuracy: 0.5480 - val_loss: 0.6586 - val_accuracy: 0.6060
# Epoch 5/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.5170
# Epoch 5: val_accuracy did not improve from 0.60600
# 63/63 [==============================] - 35s 552ms/step - loss: 0.6939 - accuracy: 0.5170 - val_loss: 0.6920 - val_accuracy: 0.5320
# Epoch 6/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5140
# Epoch 6: val_accuracy did not improve from 0.60600
# 63/63 [==============================] - 35s 554ms/step - loss: 0.6929 - accuracy: 0.5140 - val_loss: 0.6858 - val_accuracy: 0.5630
# Epoch 7/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6867 - accuracy: 0.5585
# Epoch 7: val_accuracy did not improve from 0.60600
# 63/63 [==============================] - 35s 548ms/step - loss: 0.6867 - accuracy: 0.5585 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 8/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5245
# Epoch 8: val_accuracy did not improve from 0.60600
# 63/63 [==============================] - 35s 551ms/step - loss: 0.6920 - accuracy: 0.5245 - val_loss: 0.6838 - val_accuracy: 0.6020
# Epoch 9/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6843 - accuracy: 0.5580
# Epoch 9: val_accuracy did not improve from 0.60600
# 63/63 [==============================] - 35s 549ms/step - loss: 0.6843 - accuracy: 0.5580 - val_loss: 0.6924 - val_accuracy: 0.5000
# Epoch 10/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5290
# Epoch 10: val_accuracy did not improve from 0.60600
# 63/63 [==============================] - 35s 549ms/step - loss: 0.6933 - accuracy: 0.5290 - val_loss: 0.6903 - val_accuracy: 0.5100
# Epoch 11/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6893 - accuracy: 0.5460
# Epoch 11: val_accuracy did not improve from 0.60600
# 63/63 [==============================] - 35s 549ms/step - loss: 0.6893 - accuracy: 0.5460 - val_loss: 0.6902 - val_accuracy: 0.5200
# Epoch 12/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6805 - accuracy: 0.5680
# Epoch 12: val_accuracy did not improve from 0.60600
# 63/63 [==============================] - 35s 550ms/step - loss: 0.6805 - accuracy: 0.5680 - val_loss: 0.6892 - val_accuracy: 0.5960
# Epoch 13/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6749 - accuracy: 0.6015
# Epoch 13: val_accuracy improved from 0.60600 to 0.63600, saving model to vgg16_1.h5
# 63/63 [==============================] - 41s 652ms/step - loss: 0.6749 - accuracy: 0.6015 - val_loss: 0.6563 - val_accuracy: 0.6360
# Epoch 14/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6530 - accuracy: 0.6265
# Epoch 14: val_accuracy did not improve from 0.63600
# 63/63 [==============================] - 35s 553ms/step - loss: 0.6530 - accuracy: 0.6265 - val_loss: 0.6663 - val_accuracy: 0.5980
# Epoch 15/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6271 - accuracy: 0.6660
# Epoch 15: val_accuracy improved from 0.63600 to 0.65900, saving model to vgg16_1.h5
# 63/63 [==============================] - 41s 654ms/step - loss: 0.6271 - accuracy: 0.6660 - val_loss: 0.6230 - val_accuracy: 0.6590
# Epoch 16/100
# 63/63 [==============================] - ETA: 0s - loss: 0.5709 - accuracy: 0.7040
# Epoch 16: val_accuracy did not improve from 0.65900
# 63/63 [==============================] - 35s 547ms/step - loss: 0.5709 - accuracy: 0.7040 - val_loss: 0.6315 - val_accuracy: 0.6430
# Epoch 17/100
# 63/63 [==============================] - ETA: 0s - loss: 0.5711 - accuracy: 0.7040
# Epoch 17: val_accuracy improved from 0.65900 to 0.68200, saving model to vgg16_1.h5
# 63/63 [==============================] - 42s 662ms/step - loss: 0.5711 - accuracy: 0.7040 - val_loss: 0.5893 - val_accuracy: 0.6820
# Epoch 18/100
# 63/63 [==============================] - ETA: 0s - loss: 0.5322 - accuracy: 0.7405
# Epoch 18: val_accuracy improved from 0.68200 to 0.68500, saving model to vgg16_1.h5
# 63/63 [==============================] - 41s 653ms/step - loss: 0.5322 - accuracy: 0.7405 - val_loss: 0.5950 - val_accuracy: 0.6850
# Epoch 19/100
# 63/63 [==============================] - ETA: 0s - loss: 0.5048 - accuracy: 0.7530
# Epoch 19: val_accuracy improved from 0.68500 to 0.69100, saving model to vgg16_1.h5
# 63/63 [==============================] - 41s 652ms/step - loss: 0.5048 - accuracy: 0.7530 - val_loss: 0.5907 - val_accuracy: 0.6910
# Epoch 20/100
# 63/63 [==============================] - ETA: 0s - loss: 0.4465 - accuracy: 0.7885
# Epoch 20: val_accuracy improved from 0.69100 to 0.73100, saving model to vgg16_1.h5
# 63/63 [==============================] - 41s 647ms/step - loss: 0.4465 - accuracy: 0.7885 - val_loss: 0.5608 - val_accuracy: 0.7310
# Epoch 21/100
# 63/63 [==============================] - ETA: 0s - loss: 0.4003 - accuracy: 0.8090
# Epoch 21: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 552ms/step - loss: 0.4003 - accuracy: 0.8090 - val_loss: 0.5735 - val_accuracy: 0.7080
# Epoch 22/100
# 63/63 [==============================] - ETA: 0s - loss: 0.3682 - accuracy: 0.8395
# Epoch 22: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 550ms/step - loss: 0.3682 - accuracy: 0.8395 - val_loss: 0.6400 - val_accuracy: 0.6840
# Epoch 23/100
# 63/63 [==============================] - ETA: 0s - loss: 0.3506 - accuracy: 0.8335
# Epoch 23: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 554ms/step - loss: 0.3506 - accuracy: 0.8335 - val_loss: 0.6622 - val_accuracy: 0.7190
# Epoch 24/100
# 63/63 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.8945
# Epoch 24: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 553ms/step - loss: 0.2385 - accuracy: 0.8945 - val_loss: 0.7045 - val_accuracy: 0.7140
# Epoch 25/100
# 63/63 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.9095
# Epoch 25: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 551ms/step - loss: 0.2124 - accuracy: 0.9095 - val_loss: 0.8165 - val_accuracy: 0.7040
# Epoch 26/100
# 63/63 [==============================] - ETA: 0s - loss: 0.1620 - accuracy: 0.9370
# Epoch 26: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 552ms/step - loss: 0.1620 - accuracy: 0.9370 - val_loss: 1.0624 - val_accuracy: 0.7080
# Epoch 27/100
# 63/63 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9570
# Epoch 27: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 553ms/step - loss: 0.1187 - accuracy: 0.9570 - val_loss: 1.2846 - val_accuracy: 0.6910
# Epoch 28/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9720
# Epoch 28: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 553ms/step - loss: 0.0861 - accuracy: 0.9720 - val_loss: 1.4827 - val_accuracy: 0.7010
# Epoch 29/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9775
# Epoch 29: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 550ms/step - loss: 0.0712 - accuracy: 0.9775 - val_loss: 1.6934 - val_accuracy: 0.6900
# Epoch 30/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9750
# Epoch 30: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 552ms/step - loss: 0.0905 - accuracy: 0.9750 - val_loss: 1.3648 - val_accuracy: 0.6940
# Epoch 31/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9840
# Epoch 31: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 552ms/step - loss: 0.0448 - accuracy: 0.9840 - val_loss: 1.8106 - val_accuracy: 0.6980
# Epoch 32/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9920
# Epoch 32: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 551ms/step - loss: 0.0221 - accuracy: 0.9920 - val_loss: 2.1333 - val_accuracy: 0.7170
# Epoch 33/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9900
# Epoch 33: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 550ms/step - loss: 0.0245 - accuracy: 0.9900 - val_loss: 1.9903 - val_accuracy: 0.7040
# Epoch 34/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9700
# Epoch 34: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 550ms/step - loss: 0.0921 - accuracy: 0.9700 - val_loss: 1.2302 - val_accuracy: 0.6770
# Epoch 35/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 0.9900
# Epoch 35: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 550ms/step - loss: 0.0340 - accuracy: 0.9900 - val_loss: 2.0484 - val_accuracy: 0.6960
# Epoch 36/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9930
# Epoch 36: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 552ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 2.0933 - val_accuracy: 0.7010
# Epoch 37/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9945
# Epoch 37: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 551ms/step - loss: 0.0127 - accuracy: 0.9945 - val_loss: 3.1592 - val_accuracy: 0.6890
# Epoch 38/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9920
# Epoch 38: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 552ms/step - loss: 0.0179 - accuracy: 0.9920 - val_loss: 2.9645 - val_accuracy: 0.6830
# Epoch 39/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9875
# Epoch 39: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 550ms/step - loss: 0.0381 - accuracy: 0.9875 - val_loss: 2.2210 - val_accuracy: 0.6960
# Epoch 40/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.73100
# 63/63 [==============================] - 35s 550ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.8679 - val_accuracy: 0.7000
# Epoch 40: early stopping

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %%
from keras.preprocessing import image
img = image.load_img("perro2.jpg",target_size=(224,224))
img = np.asarray(img)
plt.imshow(img)
img = np.expand_dims(img, axis=0)
from keras.models import load_model
saved_model = load_model("vgg16_1.h5")
output = saved_model.predict(img)
if output[0][0] > output[0][1]:
    print("cat")
else:
    print('dog')
# Out:
# dog

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
